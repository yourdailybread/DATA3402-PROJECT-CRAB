# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

df = pd.read_csv('train.csv')

# %%
df
# Out:
#           id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0          0   I  1.5250    1.1750  0.3750  28.973189       12.728926
# 1          1   I  1.1000    0.8250  0.2750  10.418441        4.521745
# 2          2   M  1.3875    1.1125  0.3750  24.777463       11.339800
# 3          3   F  1.7000    1.4125  0.5000  50.660556       20.354941
# 4          4   I  1.2500    1.0125  0.3375  23.289114       11.977664
# ...      ...  ..     ...       ...     ...        ...             ...
# 74046  74046   F  1.6625    1.2625  0.4375  50.660556       20.680960
# 74047  74047   I  1.0750    0.8625  0.2750  10.446791        4.323299
# 74048  74048   F  1.4875    1.2000  0.4125  29.483480       12.303683
# 74049  74049   I  1.2125    0.9625  0.3125  16.768729        8.972617
# 74050  74050   I  0.9125    0.6750  0.2000   5.386405        2.055339
#
#        Viscera Weight  Shell Weight  Age
# 0            6.647958      8.348928    9
# 1            2.324659      3.401940    8
# ...

# %%
# !wc -l train.csv
# Out:
# 74052 train.csv

# %%
df.describe()
# Out:
#                  id        Length      Diameter        Height        Weight  \
# count  74051.000000  74051.000000  74051.000000  74051.000000  74051.000000
# mean   37025.000000      1.317460      1.024496      0.348089     23.385217
# std    21376.826729      0.287757      0.237396      0.092034     12.648153
# min        0.000000      0.187500      0.137500      0.000000      0.056699
# 25%    18512.500000      1.150000      0.887500      0.300000     13.437663
# 50%    37025.000000      1.375000      1.075000      0.362500     23.799405
# 75%    55537.500000      1.537500      1.200000      0.412500     32.162508
# max    74050.000000      2.012815      1.612500      2.825000     80.101512
#
#        Shucked Weight  Viscera Weight  Shell Weight           Age
# count    74051.000000    74051.000000  74051.000000  74051.000000
# mean        10.104270        5.058386      6.723870      9.967806
# std          5.618025        2.792729      3.584372      3.175189
# ...

# %%
#plt.hist(df["Weight"], bins = 100)

# %%
#plt.hist(df["Height"], bins = 25)

# %%
#plt.hist(df["Diameter"], bins = 100)

# %%
#plt.hist(df["Age"], bins = 10)

# %% [markdown]
# **COMPARING WEIGHT BETWEEN CRAB SEXES**

# %%
df = pd.read_csv('train.csv')
df.iloc[:,1:11].hist(figsize=(16,12),bins = 50)
plt.show()

# %%
df = pd.read_csv('train.csv')

sns.barplot(x = "Sex", y = 'Weight', hue = "Sex", data = df, palette = 'Blues')
plt.title('Comparing Weight between Crab Sexes')
plt.show()

df = pd.read_csv('train.csv')

sns.barplot(x = "Sex", y = 'Shell Weight', hue = "Sex", data = df, palette = 'Blues')
plt.title('Comparing Shell Weight')
plt.show()

df = pd.read_csv('train.csv')

sns.barplot(x = "Sex", y = 'Shell Weight', hue = "Sex", data = df, palette = 'Blues')
plt.title('Comparing Shell Weight')
plt.show()

#Shucked Weight
sns.barplot(x = "Sex", y = 'Shucked Weight', hue = "Sex", data = df, palette = 'Blues')
plt.title('Comparing Shucked Weight')
plt.show()

# %%
#we can say y-axis is the length thing 
#we can say x-axis are their length, diameter, and heigth 
df = pd.read_csv('train.csv')

sns.barplot(x = "Sex", y = 'Shell Weight', hue = "Sex", data = df, palette = 'Blues')
plt.title('Comparing Shell Weight')
plt.show()

# %%
#put it in a module
"""
separate your notebooks in an orderly manner and describe what you did/what you changed 
make plots of the performance, training_model_1

"""

#dot plots, x is age y is weight 
# use sci-kit learn

# %%
df.drop('id', axis=1, inplace=True)
df.Sex = df.Sex.map({'F': 0, 'M': 1, 'I': 2})

# %%
df = df.rename(columns={'Shucked Weight': 'shucked_weight', 'Viscera Weight': 'viscera_weight', 'Shell Weight': 'shell_weight'})
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Weight', 'shucked_weight',
#        'viscera_weight', 'shell_weight', 'Age'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(df.corr(), mask=mask, annot=True, cmap='coolwarm',
                linewidths=0.2, annot_kws={"size": 7}, rasterized=True)
plt.xticks(rotation=55)
plt.show()

# %%
#does not contain weights 
selected_columns = ['Length', 'Diameter', 'Height', 'Age']
sns.pairplot(df[selected_columns], diag_kind='hist', height=2)
plt.show()
